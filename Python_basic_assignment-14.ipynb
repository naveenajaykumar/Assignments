# %%
# 1. What does RGBA stand for?

# %%
#(A)

# RGBA(Red-Green-Blue-Alpha) The format of the RGBA Value

# %%
# 2. From the Pillow module, how do you get the RGBA value of any images?

# %%
#(A)

# pip install Pillow

# from PIL import Image

# img = Image.open(‘image.png’)

# rgba = img.convert(“RGBA”)

# datas = rgba.getdata()

# %%
# 3.What is a box tuple, and how does it work?

# %%
# A box tuple is a tuple value of four integers: the left-edge x-coordinate, the top-edge y-coordinate, the width, and the height, respectively.
# for a single tuple: selective retrieval of the field contents, retrieval of information about size,iteration over all the fields
# Functions of tuple in Python
# Pre-requisites.
# Connecting to Tarantool.
# Manipulating the data. Inserting data. Querying data. Updating data. Deleting data.
# Executing stored procedures.

# %%
#4. Use your image and load in notebook then, How can you find out the width and height of an Image object?

# %%
from IPython.display import Image
Image(filename='test.png')

# %%
from PIL import Image
Image.open("test.png")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=252x200 at 0x218E030C5E0>

# %%
from PIL import Image
im = Image.open("test.png")
im.size
# Out:
# (252, 200)

# %%
# 5. What method would you call to get Image object for a 100×100 image, excluding the lower-leftquarter of it?

# %%
#(A)

# imageObj.crop((0, 50, 50, 50)). Notice that you are passing a box tuple to crop(), not four separate integer arguments.

# %%
# 6. After making changes to an Image object, how could you save it as an image file?

# %%
#(A)

# Call the imageObj.save('new_filename.png') method of the Image object.

# %%
# 7. What module contains Pillow’s shape-drawing code?

# %%
#(A)

# The ImageDraw module contains code to draw on images.

# %%
# 8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?

# %%
# ImageDraw objects have shape-drawing methods such as point(), line(), or rectangle(). 
# They are returned by passing the Image object to the ImageDraw.Draw() function.
